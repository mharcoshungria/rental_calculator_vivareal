# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dados = pd.read_csv('dados_apartamentos_limpo_zona.csv')
dados = dados.drop(['Unnamed: 0','endereco','amenidades','bairro'],axis=1)
dados.head()
# Out:
#    area  quartos  banheiros  vagas    preco  condominio zona
# 0    46        1          1      1   3400.0       600.0  Sul
# 1   240        5          5      4  15000.0      3300.0  Sul
# 2   205        3          4      2   7900.0      2380.0  Sul
# 3    56        2          2      1   2900.0       630.0  Sul
# 4    45        1          1      1   2800.0       612.0  Sul

# %%
dados = dados[dados['preco']<=20000]
dados = dados[dados['condominio']<=20000]

# %%
dados.describe()
# Out:
#               area      quartos    banheiros        vagas         preco  \
# count  5907.000000  5907.000000  5907.000000  5907.000000   5907.000000
# mean     80.198578     2.031996     1.955984     1.287286   3563.984256
# std      50.079862     0.870068     1.163312     1.032282   2804.551039
# min      11.000000     1.000000     1.000000     0.000000    500.000000
# 25%      48.000000     1.000000     1.000000     1.000000   1925.000000
# 50%      67.000000     2.000000     2.000000     1.000000   2700.000000
# 75%      96.000000     3.000000     2.000000     2.000000   4000.000000
# max     542.000000     5.000000     8.000000    40.000000  20000.000000
#
#          condominio
# count   5907.000000
# mean     935.954630
# std      733.137835
# min        0.000000
# 25%      530.000000
# 50%      770.000000
# 75%     1100.000000
# max    12500.000000

# %%
y = dados.preco
X = dados.drop(['preco'],axis=1)

# %%
X = pd.get_dummies(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#       area  quartos  banheiros  vagas  condominio  zona_Centro  zona_Leste  \
# 3258    70        2          2      2      759.00            1           0
# 3887    41        1          1      1      959.00            0           0
# 4945   115        3          4      2     1100.00            0           0
# 3462    85        2          2      1      750.00            1           0
# 3156   115        3          3      2     1720.00            1           0
#
#       zona_Norte  zona_Oeste  zona_Sul
# 3258           0           0         0
# 3887           0           1         0
# 4945           0           1         0
# 3462           0           0         0
# 3156           0           0         0

# %%
X_test.head()
# Out:
#       area  quartos  banheiros  vagas  condominio  zona_Centro  zona_Leste  \
# 1553    60        2          2      1      650.00            0           0
# 5678    56        3          2      0      715.00            0           0
# 5314   120        3          3      1     1100.00            0           0
# 3552    64        2          1      1      650.00            1           0
# 3924    35        1          1      1      790.00            0           0
#
#       zona_Norte  zona_Oeste  zona_Sul
# 1553           0           0         1
# 5678           1           0         0
# 5314           1           0         0
# 3552           0           0         0
# 3924           0           1         0

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=2)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
y_pred = dt.predict(X_test)

# %%
y_pred
# Out:
# array([3509.01033295, 3509.01033295, 3509.01033295, ..., 3509.01033295,
#        2188.27513812, 3509.01033295])

# %%
y_test
# Out:
# 1553   1800.00
# 5678   2500.00
# 5314   2100.00
# 3552   3700.00
# 3924   3690.00
#          ...
# 3991   3350.00
# 2159   2100.00
# 4967   1200.00
# 4413   1500.00
# 602    2300.00
# Name: preco, Length: 1773, dtype: float64

# %%
import lazypredict
import numpy as np
from lazypredict.Supervised import LazyRegressor

# %%
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train,X_test,y_train,y_test)
# Out:
# 100%|██████████| 42/42 [00:31<00:00,  1.34it/s]

# %%
models.head(42)
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# LGBMRegressor                                0.69       0.69   1582.57
# RandomForestRegressor                        0.69       0.69   1586.16
# HistGradientBoostingRegressor                0.68       0.68   1603.32
# GradientBoostingRegressor                    0.66       0.66   1646.54
# XGBRegressor                                 0.65       0.65   1670.44
# ExtraTreesRegressor                          0.65       0.65   1678.39
# BaggingRegressor                             0.64       0.64   1697.18
# RidgeCV                                      0.60       0.61   1782.16
# BayesianRidge                                0.60       0.61   1782.17
# LassoCV                                      0.60       0.61   1782.25
# Lasso                                        0.60       0.61   1782.43
# Ridge                                        0.60       0.61   1782.46
# LinearRegression                             0.60       0.60   1782.49
# TransformedTargetRegressor                   0.60       0.60   1782.49
# LassoLarsIC                                  0.60       0.60   1782.49
# LassoLarsCV                                  0.60       0.60   1782.49
# Lars                                         0.60       0.60   1782.49
# LarsCV                                       0.60       0.60   1782.49
# SGDRegressor                                 0.60       0.60   1790.46
# LassoLars                                    0.60       0.60   1793.22
# OrthogonalMatchingPursuitCV                  0.59       0.60   1802.98
# HuberRegressor                               0.59       0.59   1805.19
# PassiveAggressiveRegressor                   0.58       0.58   1828.54
# KNeighborsRegressor                          0.58       0.58   1832.70
# ElasticNet                                   0.57       0.58   1844.97
# AdaBoostRegressor                            0.57       0.57   1864.66
# RANSACRegressor                              0.55       0.56   1891.70
# GeneralizedLinearRegressor                   0.54       0.55   1912.08
# TweedieRegressor                             0.54       0.55   1912.08
# OrthogonalMatchingPursuit                    0.51       0.51   1975.90
# GammaRegressor                               0.51       0.51   1988.63
# ElasticNetCV                                 0.49       0.49   2023.27
# ExtraTreeRegressor                           0.45       0.45   2106.81
# MLPRegressor                                 0.44       0.44   2113.99
# DecisionTreeRegressor                        0.41       0.42   2165.20
# PoissonRegressor                             0.38       0.38   2227.32
# LinearSVR                                    0.19       0.19   2544.74
# NuSVR                                       -0.01       0.00   2836.04
# DummyRegressor                              -0.01      -0.00   2837.01
# SVR                                         -0.04      -0.03   2881.85
# KernelRidge                                 -1.00      -0.99   3998.40
# GaussianProcessRegressor                -84731.36  -84253.18 823229.60
#
#                                Time Taken
# Model
# LGBMRegressor                        0.65
# RandomForestRegressor                1.55
# HistGradientBoostingRegressor        2.50
# GradientBoostingRegressor            0.45
# XGBRegressor                         1.23
# ExtraTreesRegressor                  1.04
# BaggingRegressor                     0.19
# RidgeCV                              0.08
# BayesianRidge                        0.02
# LassoCV                              0.32
# Lasso                                0.12
# Ridge                                0.02
# LinearRegression                     0.04
# TransformedTargetRegressor           0.04
# LassoLarsIC                          0.06
# LassoLarsCV                          0.21
# Lars                                 0.06
# LarsCV                               0.09
# SGDRegressor                         0.13
# LassoLars                            0.12
# OrthogonalMatchingPursuitCV          0.06
# HuberRegressor                       0.37
# PassiveAggressiveRegressor           0.03
# KNeighborsRegressor                  0.16
# ElasticNet                           0.04
# AdaBoostRegressor                    0.15
# RANSACRegressor                      0.24
# GeneralizedLinearRegressor           0.03
# TweedieRegressor                     0.07
# OrthogonalMatchingPursuit            0.03
# GammaRegressor                       0.03
# ElasticNetCV                         0.12
# ExtraTreeRegressor                   0.03
# MLPRegressor                        11.99
# DecisionTreeRegressor                0.04
# PoissonRegressor                     0.07
# LinearSVR                            0.07
# NuSVR                                1.64
# DummyRegressor                       0.02
# SVR                                  2.05
# KernelRidge                          1.65
# GaussianProcessRegressor             3.36
